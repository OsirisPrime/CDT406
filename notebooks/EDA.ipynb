# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/erik/IES_codebase/EMG_Project/CDT406-Smart-Gripper/data/raw/M6F1O1 Dataset/subject #1/cycle #1/P1C1S1M6F1O1')

# %%
df
# Out:
# Empty DataFrame
# ...
